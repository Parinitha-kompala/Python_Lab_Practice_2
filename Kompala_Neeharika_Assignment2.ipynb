# %% [markdown]
# **Part1 -** **IRIS** **Dataset**

# %%
#Refered from Assignment 2 material
import pandas as pd
fileURL = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(fileURL, names=["Sepal Length", "Sepal Width",
"Petal Length", "Petal Width","Name"], header=None)
name=["Sepal Length", "Sepal Width",
"Petal Length", "Petal Width","Name"]

# %%
df.head(5)
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Sepal Length    float64
# Sepal Width     float64
# Petal Length    float64
# Petal Width     float64
# Name             object
# dtype: object

# %%
irisData = df.describe()

# %%
irisData.loc["variance"] = df.var()
irisData.loc["range"] = irisData.loc["max"] - irisData.loc["min"]

# %%
irisData
# Out:
#           Sepal Length  Sepal Width  Petal Length  Petal Width
# count       150.000000   150.000000    150.000000   150.000000
# mean          5.843333     3.054000      3.758667     1.198667
# std           0.828066     0.433594      1.764420     0.763161
# min           4.300000     2.000000      1.000000     0.100000
# 25%           5.100000     2.800000      1.600000     0.300000
# 50%           5.800000     3.000000      4.350000     1.300000
# 75%           6.400000     3.300000      5.100000     1.800000
# max           7.900000     4.400000      6.900000     2.500000
# variance      0.685694     0.188004      3.113179     0.582414
# range         3.600000     2.400000      5.900000     2.400000

# %%
Iris_hist = df.hist(bins = 15,grid=True,figsize=(10,10))

# %%
# Refered from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html
Iris_plot = df.boxplot(grid=True,figsize=(10,10), return_type='axes')

# %% [markdown]
# **Part2 -** **Pen-Based Handwritten Digits Dataset**

# %%
#Pen_Dataset = "pendigits_csv.csv"
#df2 = pd.read_csv(Pen_Dataset,header=0)
name2 = ["input1","input2","input3","input4","input5","input6","input7","input8","input9","input10","input11","input12","input13","input14","input15","input16","class"]
fileURL = "http://archive.ics.uci.edu/ml/machine-learning-databases/pendigits/pendigits.tra"
df2 = pd.read_csv(fileURL, names=name2, header=None)

# %%
df2.head(5)
# Out:
#    input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 0      47     100      27      81      57      37      26       0       0
# 1       0      89      27     100      42      75      29      45      15
# 2       0      57      31      68      72      90     100     100      76
# 3       0     100       7      92       5      68      19      45      86
# 4       0      67      49      83     100     100      81      80      60
#
#    input10  input11  input12  input13  input14  input15  input16  class
# 0       23       56       53      100       90       40       98      8
# 1       15       37        0       69        2      100        6      2
# 2       75       50       51       28       25       16        0      1
# 3       34      100       45       74       23       67        0      4
# 4       60       40       40       33       20       47        0      1

# %%
df2.dtypes
# Out:
# input1     int64
# input2     int64
# input3     int64
# input4     int64
# input5     int64
# input6     int64
# input7     int64
# input8     int64
# input9     int64
# input10    int64
# input11    int64
# input12    int64
# input13    int64
# input14    int64
# input15    int64
# input16    int64
# class      int64
# dtype: object

# %%
penData = df2.describe()

# %%
penData.loc["variance"] = df2.var()
penData.loc["range"] = penData.loc["max"] - penData.loc["min"]

# %%
#maxval2 = df2.max() 
#minval2 = df2.min()
#for i in range(0,len(maxval2)-1):
    #print(name2[i])
    #print(float(maxval2[i]) - float (minval2[i]))

# %%
#Refered from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html 
Pen_hist = df2.loc[:, 'input1':'input16'].hist(bins = 10,grid=True,figsize=(20,20))

# %%
#Refered from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html
Pen_boxplot = df2.loc[:, 'input1':'input16'].boxplot(grid=True,figsize=(20,20), return_type='axes')

# %% [markdown]
# **Part3**
#
# ---

# %% [markdown]
# 3.1 Consider the histograms you generated for the Iris dataset. How do the shapes of the
# histograms for petal length and petal width differ from those for sepal length and sepal width?
#
# Observations:
#
# 1. The petal data is not symetriacl in nature and is right skewed.
# 2. In the case of sepals the distrbution shows a bell curve in nature and is mostly concentrated in the center.
#
# Now consider just the petal length histogram. Is there a particular value of petal length (which
# ranges from 1.0 to 6.9) where the distribution of petal lengths (as illustrated by the histogram)
# could be best segmented into two parts?
#
#
# Observations:
#
# 1. When we increase the bins of histogram, we can observe that the data in not very much continous.
# 2. there are no values in the range of 2.5-2.8 in petal length, so we can break down the ditribution into two parts between 2.5 -2.8. that distribution is 0-2.4 and 2.8-max.
#
# 3.2 Now consider the boxplots you generated for the Iris dataset. There should be four boxplots, one for each feature. Based upon these boxplots, is there a pair of features that appear to
# have significantly different medians? Recall that the degree of overlap between variabilities is an
# important initial indicator of the likelihood that differences in means or medians are meaningful.
#
# Observations:
#
# 1. Sepal lenght and petal width are far apart we can tell that by looking at the boxplot, also we can conclude that by looking at the median data, as they are very far aprt compared to the combination with other two medians.
# 2. The median being so far apart in this case is because there is no data overlap.
#
# Also, based solely upon the box plots, which feature appears to explain the greatest amount of
# the data?
#
# Observations:
#
# 1. The largest data distribution seems to be that of 'Petal Length', even the distribution seems very divided and covers large part of the graph.
# 2. The mean is also much nearer to the third quartile unlike central position of other plots.
#
# 3.3 Lastly, consider the boxplots you generated for the Digits dataset. Do you observe any
# outliers? If so, for what features?
#
# Observations:
#
# 1. input2 & input4 have outliers, in the images (boxplot) we can see the black dots pointing out the disturbance.
#
# Now consider the corresponding histograms. What sort of
# distribution do the second and forth features display? With that in mind, explain the outliers,
# or lack thereof, in terms of what you observe from the histograms
#
# Observations:
#
# 1. From the plot of distribution of 2nd and 4th inputs we can observe that the features are towards the top of chart, meanind the data is left skewed.
# 2. there seems to be more outliers for 2nd than 4th.
# 3. The feature distribution and median is alomst similar to each other.
# 4. The median is to the right of the mean,hence we can say that smaller values are outliers.
